# %% [markdown]
# ### Daniel's Cleaning Notebook

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../alt_data/old_quarterly_data/merged_df.csv')
df.head()
# Out:
#    Unnamed: 0  personal_saving_as_%_of_income commercial_and_industrial_loans  \
# 0  1947-01-01                             7.4             11.5246666666666667
# 1  1947-04-01                             5.0             12.2629666666666667
# 2  1947-07-01                             7.1             13.0715000000000000
# 3  1947-10-01                             5.8             13.9112666666666667
# 4  1948-01-01                             6.9             14.5712666666666667
#
#      employment_level labor_force_participation_rate      consumer_loans  \
# 0                 NaN                            NaN  4.2961333333333333
# 1                 NaN                            NaN  4.7079666666666667
# 2                 NaN                            NaN  5.1155666666666667
# 3                 NaN                            NaN  5.5139000000000000
# 4  57976.000000000000            58.6666666666666667  5.9029333333333333
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          297 non-null    object
#  1   personal_saving_as_%_of_income      296 non-null    float64
#  2   commercial_and_industrial_loans     297 non-null    object
#  3   employment_level                    293 non-null    object
#  4   labor_force_participation_rate      293 non-null    object
#  5   consumer_loans                      297 non-null    object
#  6   corporate_profits_after_tax         296 non-null    float64
#  7   personal_consumtion_expendatures    249 non-null    object
#  8   ecommerce_retail_sales              85 non-null     float64
#  9   gross_output_of_all_industries      64 non-null     float64
#  10  household_debt_to_gdp               63 non-null     float64
# ...

# %% [markdown]
# > Interpolate reference: https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/

# %%
df[df['household_debt_service_payments']==10.61574][['Unnamed: 0', 'household_debt_service_payments']]
# Out:
#      Unnamed: 0  household_debt_service_payments
# 132  1980-01-01                         10.61574

# %%
df['household_debt_service_payments'].values
# Out:
# array([      nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
#              nan,       nan,       nan,       nan,       nan,       nan,
# ...

# %%
df['personal_saving_as_%_of_income'].interpolate().values
# Out:
# array([ 7.4,  5. ,  7.1,  5.8,  6.9,  8.6, 10. ,  9.7,  7.8,  6.8,  7.2,
#         6.3, 11.5,  9.8,  6.3,  9.7,  7.6, 12.2, 12.2, 11.5, 11.2, 10.6,
#        11.9, 10.7, 10.6, 11.2, 10.9, 11.2, 11.3, 10.3,  9.9,  9.9,  9.3,
#         9.5, 10. ,  9.9, 10.6, 11.1, 11.3, 11.5, 11.1, 11.6, 11.4, 10.7,
#        11.2, 11.1, 11.6, 11.8, 10.7, 10.8,  9.7, 10.2, 10.3,  9.7, 10.2,
#        10. , 10.9, 10.9, 11.7, 11.6, 11.6, 11.4, 11.1, 10.7, 10.8, 10.7,
#        10.4, 11.1, 11.1, 11.9, 11.4, 12.1, 11.2, 11.2, 12. , 11.4, 11. ,
#        11. , 11. , 11.7, 12.5, 11.9, 12.4, 12.5, 11.9, 12. , 10.6, 10.9,
#        10.1, 10.3, 11.7, 11.6, 12. , 12.6, 13.3, 13.3, 13.4, 13.8, 13.6,
#        13.1, 12.4, 11.6, 12. , 13.4, 12.6, 13.3, 13.4, 14.5, 14. , 12.9,
#        12.6, 13.7, 12.8, 15.3, 12.9, 12.7, 12.1, 11.8, 11.6, 11. , 10.1,
#        10.5, 10.8, 11.2, 11.3, 10.4, 10.7, 10.5, 11.1, 10.4,  9.9,  9.8,
#        10.1, 11.3, 11.4, 11.4, 10.9, 10.9, 12.3, 12.9, 12.3, 12.5, 12.3,
# ...
