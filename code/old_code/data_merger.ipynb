# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 10)

# %%
file_list = os.listdir('../../alt_data/old_quarterly_data/') 
number_files = len(file_list)
print (number_files)
# Out:
# 24

# %%
file_list
# Out:
# ['.ipynb_checkpoints',
#  'A072RC1Q156SBEA.csv',
#  'BUSLOANS.csv',
#  'CE16OV.csv',
#  'CIVPART.csv',
#  'CONSUMER.csv',
#  'CP.csv',
#  'DPCCRC1M027SBEA.csv',
#  'ECOMPCTSA.csv',
#  'GOAI.csv',
#  'HDTGPDUSQ163N.csv',
#  'IURSA.csv',
#  'LES1252881600Q.csv',
#  'LNS15000000.csv',
#  'M1V.csv',
#  'merged_df.csv',
#  'PCE.csv',
#  'PSAVERT.csv',
#  'RRVRUSQ156N.csv',
#  'TDSP.csv',
#  'UEMP27OV.csv',
#  'UEMPMEAN.csv',
#  'UNRATE.csv',
#  'W825RC1.csv']

# %%
df1 = pd.read_csv("../../alt_data/old_quarterly_data/A072RC1Q156SBEA.csv", index_col='DATE')
df2 = pd.read_csv("../../alt_data/old_quarterly_data/BUSLOANS.csv", index_col='DATE')
df3 = pd.read_csv("../../alt_data/old_quarterly_data/CE16OV.csv", index_col='DATE')
df4 = pd.read_csv("../../alt_data/old_quarterly_data/CIVPART.csv", index_col='DATE')
df5 = pd.read_csv("../../alt_data/old_quarterly_data/CONSUMER.csv", index_col='DATE')
df6 = pd.read_csv("../../alt_data/old_quarterly_data/CP.csv", index_col='DATE')
df7 = pd.read_csv("../../alt_data/old_quarterly_data/DPCCRC1M027SBEA.csv", index_col='DATE')
df8 = pd.read_csv("../../alt_data/old_quarterly_data/ECOMPCTSA.csv", index_col='DATE')
df9 = pd.read_csv("../../alt_data/old_quarterly_data/GOAI.csv", index_col='DATE')
df10 = pd.read_csv("../../alt_data/old_quarterly_data/HDTGPDUSQ163N.csv", index_col='DATE')
df11 = pd.read_csv("../../alt_data/old_quarterly_data/IURSA.csv", index_col='DATE')
df12 = pd.read_csv("../../alt_data/old_quarterly_data/LES1252881600Q.csv", index_col='DATE')
df13 = pd.read_csv("../../alt_data/old_quarterly_data/LNS15000000.csv", index_col='DATE')
df14 = pd.read_csv("../../alt_data/old_quarterly_data/M1V.csv", index_col='DATE')
df15 = pd.read_csv("../../alt_data/old_quarterly_data/PCE.csv", index_col='DATE')
df16 = pd.read_csv("../../alt_data/old_quarterly_data/PSAVERT.csv", index_col='DATE')
df17 = pd.read_csv("../../alt_data/old_quarterly_data/RRVRUSQ156N.csv", index_col='DATE')
df18 = pd.read_csv("../../alt_data/old_quarterly_data/TDSP.csv", index_col='DATE')
df19 = pd.read_csv("../../alt_data/old_quarterly_data/UEMP27OV.csv", index_col='DATE')
df20 = pd.read_csv("../../alt_data/old_quarterly_data/UEMPMEAN.csv", index_col='DATE')
df21 = pd.read_csv("../../alt_data/old_quarterly_data/UNRATE.csv", index_col='DATE')
df22 = pd.read_csv("../../alt_data/old_quarterly_data/W825RC1.csv", index_col='DATE')

# %%
df_merged_all = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22],axis = 1, )

# %%
df_merged_all
# Out:
#             A072RC1Q156SBEA               BUSLOANS               CE16OV  \
# DATE
# 1947-01-01              7.4    11.5246666666666667                  NaN
# 1947-04-01              5.0    12.2629666666666667                  NaN
# 1947-07-01              7.1    13.0715000000000000                  NaN
# 1947-10-01              5.8    13.9112666666666667                  NaN
# 1948-01-01              6.9    14.5712666666666667   57976.000000000000
# ...                     ...                    ...                  ...
# 2020-01-01              9.6  2431.6499666666666667  157642.333333333333
# 2020-04-01             26.0  2967.9755666666666667  137564.666666666667
# 2020-07-01             15.7  2809.0195666666666667  146198.666666666667
# 2020-10-01             13.0  2654.2818000000000000  149769.333333333333
# 2021-01-01              NaN                      .                    .
#
#                         CIVPART               CONSUMER        CP  \
# DATE
# ...

# %%
file_list
# Out:
# ['.ipynb_checkpoints',
#  'A072RC1Q156SBEA.csv',
#  'BUSLOANS.csv',
#  'CE16OV.csv',
#  'CIVPART.csv',
#  'CONSUMER.csv',
#  'CP.csv',
#  'DPCCRC1M027SBEA.csv',
#  'ECOMPCTSA.csv',
#  'GOAI.csv',
#  'HDTGPDUSQ163N.csv',
#  'IURSA.csv',
#  'LES1252881600Q.csv',
#  'LNS15000000.csv',
#  'M1V.csv',
#  'merged_df.csv',
#  'PCE.csv',
#  'PSAVERT.csv',
#  'RRVRUSQ156N.csv',
#  'TDSP.csv',
#  'UEMP27OV.csv',
#  'UEMPMEAN.csv',
#  'UNRATE.csv',
#  'W825RC1.csv']

# %%
df_merged_all.rename(columns={
    'A072RC1Q156SBEA': 'personal_saving_as_%_of_income',
    'BUSLOANS': 'commercial_and_industrial_loans',
    'CE16OV': 'employment_level',
    'CIVPART': 'labor_force_participation_rate',
    'CONSUMER': 'consumer_loans',
    'CP': 'corporate_profits_after_tax',
    'DPCCRC1M027SBEA': 'personal_consumtion_expendatures',
    'ECOMPCTSA': 'ecommerce_retail_sales',
    'GOAI': 'gross_output_of_all_industries',
    'HDTGPDUSQ163N': 'household_debt_to_gdp',
    'IURSA': 'insured_unemployment_rate',
    'LES1252881600Q': 'median_weekly_real_earnings',
    'LNS15000000': 'not_in_labor_force',
    'M1V': 'velocity_of_M1_money_stock',
    'PCE': 'personal_consumtion_expendatures',
    'PSAVERT': 'personal_savings_rate',
    'RRVRUSQ156N': 'rental_vacancy_rate',
    'TDSP': 'household_debt_service_payments',
    'UEMP27OV': 'number_unemployed_for_27_weeks',
    'UEMPMEAN': 'average_weeks_unemployed',
    'UNRATE': 'unemployment_rate',
    'W825RC1': 'goverment_unemployment_insurance',
}, inplace=True)

# %%
df_merged_all.index
# Out:
# Index(['1947-01-01', '1947-04-01', '1947-07-01', '1947-10-01', '1948-01-01',
#        '1948-04-01', '1948-07-01', '1948-10-01', '1949-01-01', '1949-04-01',
#        ...
#        '2018-10-01', '2019-01-01', '2019-04-01', '2019-07-01', '2019-10-01',
#        '2020-01-01', '2020-04-01', '2020-07-01', '2020-10-01', '2021-01-01'],
#       dtype='object', name='DATE', length=297)

# %%
# merged_df = df_merged_all.to_csv('data/merged_df.csv')
